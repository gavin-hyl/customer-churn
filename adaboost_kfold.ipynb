# %%
import pandas as pd
from utils import *

# %%
raw = numerize_csv('train.csv', expand_classes=True)
# combined=combine_related_columns(raw)

# Data
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
import numpy as np
import matplotlib.pyplot as plt

Y = raw['Discontinued'].to_numpy()
X = raw.drop('Discontinued', axis=1).to_numpy()

kf = KFold(n_splits=5)

# X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=0, train_size = .75)
# Out:
# (5343, 26)

# %%
def get_cross_validation_accuracies(clf, kf, X, Y):
    fold_accs = np.zeros((kf.get_n_splits(X), 6))
    for j, (train_index, test_index) in enumerate(kf.split(X)):
        X_train = X[train_index]
        X_test = X[test_index]
        y_train = Y[train_index]
        y_test = Y[test_index]

        clf.fit(X_train, y_train)
        y_test_preds = clf.predict(X_test)
        y_train_preds = clf.predict(X_train)
        y_test_prob_preds = clf.predict_proba(X_test)
        y_train_prob_preds = clf.predict_proba(X_train)

        fold_accs[j,0] = roc_auc_score(y_test, y_test_preds)
        fold_accs[j,1] = roc_auc_score(y_train, y_train_preds)
        fold_accs[j,2] = roc_auc_score(y_test, y_test_prob_preds[:, 1])
        fold_accs[j,3] = roc_auc_score(y_train, y_train_prob_preds[:, 1])
        fold_accs[j,4] = accuracy_score(y_test, y_test_preds)
        fold_accs[j,5] = accuracy_score(y_train, y_train_preds)

    return np.average(fold_accs, axis=0)

def plot_accuracies(x_vals, accuracies, condensed, title, xlabel, ylabel):
    if not condensed:
        plt.plot(x_vals, accuracies[:,0], label="ROC AUC Testing")
        plt.plot(x_vals, accuracies[:,1], label="ROC AUC Training")
        plt.plot(x_vals, accuracies[:,2], label="ROC AUC Testing with Probabilities")
        plt.plot(x_vals, accuracies[:,3], label="ROC AUC Training with Probabilities")
        plt.plot(x_vals, accuracies[:,4], label="Testing")
        plt.plot(x_vals, accuracies[:,5], label="Training")
    else:
        plt.plot(x_vals, accuracies[:,0], label="Testing")
        plt.plot(x_vals, accuracies[:,1], label="Training")
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend()

# %%
# Test with different max_depths
max_depths = [1, 2, 3, 4, 5]
accuracies = np.zeros((len(max_depths), 6))
for (i, depth) in enumerate(max_depths):
    print("Depth: " + str(depth))
    base_estimator = DecisionTreeClassifier(criterion="gini", max_depth=depth)
    clf = AdaBoostClassifier(estimator=base_estimator, n_estimators=20, random_state=0)

    accuracies[i] = get_cross_validation_accuracies(clf, kf, X, Y)

    print(f'ROC AUC Testing Accuracy: {accuracies[i,0]}')
    print(f'ROC AUC Training Accuracy: {accuracies[i,1]}')
    print(f'ROC AUC Testing Accuracy with Probabilities: {accuracies[i,2]}')
    print(f'ROC AUC Training Accuracy with Probabilities: {accuracies[i,3]}')
    print(f'Testing Accuracy: {accuracies[i,4]}')
    print(f'Training Accuracy: {accuracies[i,5]}')

plot_accuracies(max_depths, accuracies, False, "AdaBoost Max Depth vs. Accuracy", "Max Depth", "Accuracy")
# Out:
# Depth: 1
# ROC AUC Testing Accuracy: 0.7150283182542838
# ROC AUC Training Accuracy: 0.7216096124253437
# ROC AUC Testing Accuracy with Probabilities: 0.8458526763264833
# ROC AUC Training Accuracy with Probabilities: 0.8523336172706903
# Testing Accuracy: 0.8038523524733467
# Training Accuracy: 0.8084409635850663
# Depth: 2
# ROC AUC Testing Accuracy: 0.7096465239232131
# ROC AUC Training Accuracy: 0.7290300176701398
# ROC AUC Testing Accuracy with Probabilities: 0.8357844273896393
# ROC AUC Training Accuracy with Probabilities: 0.8669583237633253
# Testing Accuracy: 0.7980507877781399
# Training Accuracy: 0.8130733853820326
# Depth: 3
# ROC AUC Testing Accuracy: 0.7057244292389877
# ROC AUC Training Accuracy: 0.7559886911492598
# ROC AUC Testing Accuracy with Probabilities: 0.8110480678193795
# ROC AUC Training Accuracy with Probabilities: 0.8920610245600258
# Testing Accuracy: 0.7896310038083827
# Training Accuracy: 0.8262210728818614
# Depth: 4
# ROC AUC Testing Accuracy: 0.7027137129292214
# ROC AUC Training Accuracy: 0.7913649367577891
# ROC AUC Testing Accuracy with Probabilities: 0.8068198020969535
# ROC AUC Training Accuracy with Probabilities: 0.9204689714033426
# Testing Accuracy: 0.7827063691433416
# Training Accuracy: 0.8501306799990148
# Depth: 5
# ROC AUC Testing Accuracy: 0.6833294363461906
# ROC AUC Training Accuracy: 0.8455345690708708
# ROC AUC Testing Accuracy with Probabilities: 0.7794796884403596
# ROC AUC Training Accuracy with Probabilities: 0.9553609163744469
# Testing Accuracy: 0.7652986970216136
# Training Accuracy: 0.8863929704154317

# %%
# Test with different n_estimators
num_estimators = [10, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 100, 200, 300, 400, 500]
accuracies = np.zeros((len(num_estimators), 6))
for (i, num) in enumerate(num_estimators):
    print("Number of Estimators: " + str(num))
    
    base_estimator = DecisionTreeClassifier(criterion="gini", max_depth=1)
    clf = AdaBoostClassifier(estimator=base_estimator, n_estimators=num, random_state=0)

    accuracies[i] = get_cross_validation_accuracies(clf, kf, X, Y)

    print(f'ROC AUC Testing Accuracy: {accuracies[i,0]}')
    print(f'ROC AUC Training Accuracy: {accuracies[i,1]}')
    print(f'ROC AUC Testing Accuracy with Probabilities: {accuracies[i,2]}')
    print(f'ROC AUC Training Accuracy with Probabilities: {accuracies[i,3]}')
    print(f'Testing Accuracy: {accuracies[i,4]}')
    print(f'Training Accuracy: {accuracies[i,5]}')

plot_accuracies(num_estimators, accuracies[:,[2,3]], True, "AdaBoost Number of Estimators vs. Accuracy", "Number of Estimators", "Accuracy")
# Out:
# Number of Estimators: 10
# ROC AUC Testing Accuracy: 0.7098849572261356
# ROC AUC Training Accuracy: 0.7111536134781484
# ROC AUC Testing Accuracy with Probabilities: 0.8390940491086551
# ROC AUC Training Accuracy with Probabilities: 0.8432948428101661
# Testing Accuracy: 0.7961814569954068
# Training Accuracy: 0.7987553847964162
# Number of Estimators: 25
# ROC AUC Testing Accuracy: 0.7181032337587792
# ROC AUC Training Accuracy: 0.7259281536573268
# ROC AUC Testing Accuracy with Probabilities: 0.8450175720786071
# ROC AUC Training Accuracy with Probabilities: 0.8543419584040569
# Testing Accuracy: 0.8057248364707821
# Training Accuracy: 0.8108272897186032
# Number of Estimators: 30
# ROC AUC Testing Accuracy: 0.7169033718281037
# ROC AUC Training Accuracy: 0.7243474240402294
# ROC AUC Testing Accuracy with Probabilities: 0.8446903767994989
# ROC AUC Training Accuracy with Probabilities: 0.8558193364761848
# Testing Accuracy: 0.8070355227154083
# Training Accuracy: 0.8116226660865233
# Number of Estimators: 35
# ROC AUC Testing Accuracy: 0.7152948858586139
# ROC AUC Training Accuracy: 0.7220736370250803
# ROC AUC Testing Accuracy with Probabilities: 0.8442593921886387
# ROC AUC Training Accuracy with Probabilities: 0.8569086812805926
# Testing Accuracy: 0.804976999050532
# Training Accuracy: 0.8106400457546925
# Number of Estimators: 40
# ROC AUC Testing Accuracy: 0.714628371178858
# ROC AUC Training Accuracy: 0.7244119042198549
# ROC AUC Testing Accuracy with Probabilities: 0.8441070742397597
# ROC AUC Training Accuracy with Probabilities: 0.8582480207746117
# Testing Accuracy: 0.8049764735147482
# Training Accuracy: 0.8125584152238341
# Number of Estimators: 45
# ROC AUC Testing Accuracy: 0.717306320793866
# ROC AUC Training Accuracy: 0.727391086561983
# ROC AUC Testing Accuracy with Probabilities: 0.8446145365127302
# ROC AUC Training Accuracy with Probabilities: 0.8591431911874855
# Testing Accuracy: 0.8059135038171416
# Training Accuracy: 0.8133070736426153
# Number of Estimators: 50
# ROC AUC Testing Accuracy: 0.7146574279995525
# ROC AUC Training Accuracy: 0.7262023178654652
# ROC AUC Testing Accuracy with Probabilities: 0.8450010974971903
# ROC AUC Training Accuracy with Probabilities: 0.8598682751323518
# Testing Accuracy: 0.8051649656825133
# Training Accuracy: 0.8131199500857902
# Number of Estimators: 55
# ROC AUC Testing Accuracy: 0.7144584892994426
# ROC AUC Training Accuracy: 0.7266994692873325
# ROC AUC Testing Accuracy with Probabilities: 0.8450310815693994
# ROC AUC Training Accuracy with Probabilities: 0.8604541879953743
# Testing Accuracy: 0.8053518812429271
# Training Accuracy: 0.8139153483459076
# Number of Estimators: 60
# ROC AUC Testing Accuracy: 0.7127416708426381
# ROC AUC Training Accuracy: 0.7255877822474714
# ROC AUC Testing Accuracy with Probabilities: 0.844722076605662
# ROC AUC Training Accuracy with Probabilities: 0.8612202230677191
# Testing Accuracy: 0.8036673638774732
# Training Accuracy: 0.8137281810046877
# Number of Estimators: 65
# ROC AUC Testing Accuracy: 0.7143896326304976
# ROC AUC Training Accuracy: 0.7258383856501366
# ROC AUC Testing Accuracy with Probabilities: 0.8446542374390884
# ROC AUC Training Accuracy with Probabilities: 0.8618052201094626
# Testing Accuracy: 0.8044162523692904
# Training Accuracy: 0.8134942957143287
# Number of Estimators: 70
# ROC AUC Testing Accuracy: 0.7133295117975023
# ROC AUC Training Accuracy: 0.7255074781223619
# ROC AUC Testing Accuracy with Probabilities: 0.8450945480036915
# ROC AUC Training Accuracy with Probabilities: 0.8623948110254659
# Testing Accuracy: 0.8051646153253241
# Training Accuracy: 0.8138686960733608
# Number of Estimators: 100
# ROC AUC Testing Accuracy: 0.7120609425911215
# ROC AUC Training Accuracy: 0.7300808264812536
# ROC AUC Testing Accuracy with Probabilities: 0.8448079196221935
# ROC AUC Training Accuracy with Probabilities: 0.8652131790801212
# Testing Accuracy: 0.8023577287044142
# Training Accuracy: 0.8151788236775062
# Number of Estimators: 200
# ROC AUC Testing Accuracy: 0.710656708218904
# ROC AUC Training Accuracy: 0.734371498356319
# ROC AUC Testing Accuracy with Probabilities: 0.8431202554799873
# ROC AUC Training Accuracy with Probabilities: 0.8707130073829573
# Testing Accuracy: 0.801796456487389
# Training Accuracy: 0.8180328328229717
# Number of Estimators: 300
# ROC AUC Testing Accuracy: 0.7114724254650563
# ROC AUC Training Accuracy: 0.7373044005899646
# ROC AUC Testing Accuracy with Probabilities: 0.8415772124552416
# ROC AUC Training Accuracy with Probabilities: 0.8742897227306619
# Testing Accuracy: 0.8014217494735885
# Training Accuracy: 0.8199980297022389
# Number of Estimators: 400
# ROC AUC Testing Accuracy: 0.7109625225899681
# ROC AUC Training Accuracy: 0.7388004102031335
# ROC AUC Testing Accuracy with Probabilities: 0.8409794835442627
# ROC AUC Training Accuracy with Probabilities: 0.8772558906053003
# Testing Accuracy: 0.8002990298609433
# Training Accuracy: 0.8213549628243124
# Number of Estimators: 500
# ROC AUC Testing Accuracy: 0.7087771367460197
# ROC AUC Training Accuracy: 0.7404657035110861
# ROC AUC Testing Accuracy with Probabilities: 0.8391183689474868
# ROC AUC Training Accuracy with Probabilities: 0.8795708168577854
# Testing Accuracy: 0.7976797595148254
# Training Accuracy: 0.8221971666023584

# %%
# Compare Gini vs. Entropy loss
num_trials = 100
accuracies = np.zeros((100, 6))
print("Gini: ")
for i in range(num_trials):
    base_estimator = DecisionTreeClassifier(criterion="gini", max_depth=1)
    clf = AdaBoostClassifier(estimator=base_estimator, n_estimators=40)
    
    accuracies[i] = get_cross_validation_accuracies(clf, kf, X, Y)

print(f'ROC AUC Testing Accuracy: {np.mean(accuracies[:,0])}')
print(f'ROC AUC Training Accuracy: {np.mean(accuracies[:,1])}')
print(f'ROC AUC Testing Accuracy with Probabilities: {np.mean(accuracies[:,2])}')
print(f'ROC AUC Training Accuracy with Probabilities: {np.mean(accuracies[:,3])}')
print(f'Testing Accuracy: {np.mean(accuracies[:,4])}')
print(f'Training Accuracy: {np.mean(accuracies[:,5])}')

num_trials = 100
accuracies = np.zeros((100, 6))
print("Entropy: ")
for i in range(num_trials):
    base_estimator = DecisionTreeClassifier(criterion="entropy", max_depth=1)
    clf = AdaBoostClassifier(estimator=base_estimator, n_estimators=40)
    
    accuracies[i] = get_cross_validation_accuracies(clf, kf, X, Y)

print(f'ROC AUC Testing Accuracy: {np.mean(accuracies[:,0])}')
print(f'ROC AUC Training Accuracy: {np.mean(accuracies[:,1])}')
print(f'ROC AUC Testing Accuracy with Probabilities: {np.mean(accuracies[:,2])}')
print(f'ROC AUC Training Accuracy with Probabilities: {np.mean(accuracies[:,3])}')
print(f'Testing Accuracy: {np.mean(accuracies[:,4])}')
print(f'Training Accuracy: {np.mean(accuracies[:,5])}')

# Entropy seems to slightly better (perhaps negligible)
# Out:
# Gini:
# ROC AUC Testing Accuracy: 0.714628371178858
# ROC AUC Training Accuracy: 0.7244119042198546
# ROC AUC Testing Accuracy with Probabilities: 0.8441070742397596
# ROC AUC Training Accuracy with Probabilities: 0.8582480207746117
# Testing Accuracy: 0.804976473514748
# Training Accuracy: 0.8125584152238341
# Entropy:
# ROC AUC Testing Accuracy: 0.7186180082043258
# ROC AUC Training Accuracy: 0.7257269384060473
# ROC AUC Testing Accuracy with Probabilities: 0.8448482064957108
# ROC AUC Training Accuracy with Probabilities: 0.8581625069908974
# Testing Accuracy: 0.8081582423280532
# Training Accuracy: 0.8131199281935924

# %%
# Generate submission using test.csv

raw_test = numerize_csv_test('test.csv', expand_classes=True)
#X_test = combine_related_columns_test(raw_test)

base_estimator = DecisionTreeClassifier(criterion="gini", max_depth=1)
clf = AdaBoostClassifier(estimator=base_estimator, n_estimators=30)
clf.fit(X_train, y_train)
y_test_prob_preds = clf.predict_proba(raw_test)
write_submission(y_test_prob_preds[:, 1])
