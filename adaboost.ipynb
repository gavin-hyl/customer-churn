# %%
import pandas as pd
from utils import *

# %%
raw = numerize_csv('train.csv')
# combined=combine_related_columns(raw)

# Data
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

Y = # combined['Discontinued']
Y = raw['Discontinued']
X = raw.drop('Discontinued', axis=1)  
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=0, train_size = .75)

# %%
# Test with different max_depths
max_depths = [1, 2, 3, 4, 5]
for depth in max_depths:
    print("Depth: " + str(depth))
    base_estimator = DecisionTreeClassifier(criterion="gini", max_depth=depth)
    clf = AdaBoostClassifier(estimator=base_estimator, n_estimators=100, random_state=0)
    clf.fit(X_train, y_train)
    y_test_preds = clf.predict(X_test)
    y_train_preds = clf.predict(X_train)
    y_test_prob_preds = clf.predict_proba(X_test)
    y_train_prob_preds = clf.predict_proba(X_train)

    roc_auc_testing_accuracy = roc_auc_score(y_test, y_test_preds)
    roc_auc_training_accuracy = roc_auc_score(y_train, y_train_preds)
    prob_roc_auc_testing_accuracy = roc_auc_score(y_test, y_test_prob_preds[:, 1])
    prob_roc_auc_training_accuracy = roc_auc_score(y_train, y_train_prob_preds[:, 1])
    testing_accuracy = accuracy_score(y_test, y_test_preds)
    training_accuracy = accuracy_score(y_train, y_train_preds)

    print(f'ROC AUC Testing Accuracy: {roc_auc_testing_accuracy}')
    print(f'ROC AUC Training Accuracy: {roc_auc_training_accuracy}')
    print(f'ROC AUC Testing Accuracy with Probabilities: {prob_roc_auc_testing_accuracy}')
    print(f'ROC AUC Training Accuracy with Probabilities: {prob_roc_auc_training_accuracy}')
    print(f'Testing Accuracy: {testing_accuracy}')
    print(f'Training Accuracy: {training_accuracy}')

# Depth 1 seems to be best, model is very prone to overfitting, maybe RandomForest is the way to go
# Out:
# Depth: 1
# ROC AUC Testing Accuracy: 0.7254262431669003
# ROC AUC Training Accuracy: 0.7239392802225376
# ROC AUC Testing Accuracy with Probabilities: 0.8535169234431563
# ROC AUC Training Accuracy with Probabilities: 0.8608911530486154
# Testing Accuracy: 0.8091317365269461
# Training Accuracy: 0.8075867232343399
# Depth: 2
# ROC AUC Testing Accuracy: 0.7041496474222195
# ROC AUC Training Accuracy: 0.7866878374739997
# ROC AUC Testing Accuracy with Probabilities: 0.8172227496131661
# ROC AUC Training Accuracy with Probabilities: 0.9169968982753847
# Testing Accuracy: 0.7776946107784432
# Training Accuracy: 0.8492637883703519
# Depth: 3
# ROC AUC Testing Accuracy: 0.6926012372881848
# ROC AUC Training Accuracy: 0.8900261272266136
# ROC AUC Testing Accuracy with Probabilities: 0.7791896372034152
# ROC AUC Training Accuracy with Probabilities: 0.9769659838417304
# Testing Accuracy: 0.7702095808383234
# Training Accuracy: 0.9183928125779885
# Depth: 4
# ROC AUC Testing Accuracy: 0.6704145292818096
# ROC AUC Training Accuracy: 0.993834462878583
# ROC AUC Testing Accuracy with Probabilities: 0.7633867788412687
# ROC AUC Training Accuracy with Probabilities: 0.9998984726560517
# Testing Accuracy: 0.7470059880239521
# Training Accuracy: 0.994509608185675
# Depth: 5
# ROC AUC Testing Accuracy: 0.6534127032511474
# ROC AUC Training Accuracy: 0.9958662949138014
# ROC AUC Testing Accuracy with Probabilities: 0.7944017209395493
# ROC AUC Training Accuracy with Probabilities: 0.999983774902312
# Testing Accuracy: 0.749251497005988
# Training Accuracy: 0.997504367357125

# %%
# Test with different n_estimators
num_estimators = [10, 25, 50, 100, 200, 400, 700, 1000]
for num in num_estimators:
    print("Number of Estimators: " + str(num))
    base_estimator = DecisionTreeClassifier(criterion="entropy", max_depth=1)
    clf = AdaBoostClassifier(estimator=base_estimator, n_estimators=num, random_state=0)
    clf.fit(X_train, y_train)
    y_test_preds = clf.predict(X_test)
    y_train_preds = clf.predict(X_train)
    y_test_prob_preds = clf.predict_proba(X_test)
    y_train_prob_preds = clf.predict_proba(X_train)

    roc_auc_testing_accuracy = roc_auc_score(y_test, y_test_preds)
    roc_auc_training_accuracy = roc_auc_score(y_train, y_train_preds)
    prob_roc_auc_testing_accuracy = roc_auc_score(y_test, y_test_prob_preds[:, 1])
    prob_roc_auc_training_accuracy = roc_auc_score(y_train, y_train_prob_preds[:, 1])
    testing_accuracy = accuracy_score(y_test, y_test_preds)
    training_accuracy = accuracy_score(y_train, y_train_preds)

    print(f'ROC AUC Testing Accuracy: {roc_auc_testing_accuracy}')
    print(f'ROC AUC Training Accuracy: {roc_auc_training_accuracy}')
    print(f'ROC AUC Testing Accuracy with Probabilities: {prob_roc_auc_testing_accuracy}')
    print(f'ROC AUC Training Accuracy with Probabilities: {prob_roc_auc_training_accuracy}')
    print(f'Testing Accuracy: {testing_accuracy}')
    print(f'Training Accuracy: {training_accuracy}')

# 200 seems to be best, after that model is overfitting on training data
# Out:
# Number of Estimators: 10
# ROC AUC Testing Accuracy: 0.7392303382366177
# ROC AUC Training Accuracy: 0.7181152733752252
# ROC AUC Testing Accuracy with Probabilities: 0.8455479978981777
# ROC AUC Training Accuracy with Probabilities: 0.8370445968496966
# Testing Accuracy: 0.8076347305389222
# Training Accuracy: 0.798103319191415
# Number of Estimators: 25
# ROC AUC Testing Accuracy: 0.7233128086325672
# ROC AUC Training Accuracy: 0.7200756185938978
# ROC AUC Testing Accuracy with Probabilities: 0.8533761245765147
# ROC AUC Training Accuracy with Probabilities: 0.8491894840804481
# Testing Accuracy: 0.8046407185628742
# Training Accuracy: 0.8068380334414774
# Number of Estimators: 50
# ROC AUC Testing Accuracy: 0.7135454315848146
# ROC AUC Training Accuracy: 0.7196333641985025
# ROC AUC Testing Accuracy with Probabilities: 0.8525719743484786
# ROC AUC Training Accuracy with Probabilities: 0.8547816808687141
# Testing Accuracy: 0.8038922155688623
# Training Accuracy: 0.8093336660843524
# Number of Estimators: 100
# ROC AUC Testing Accuracy: 0.7182629193846655
# ROC AUC Training Accuracy: 0.7237685150854855
# ROC AUC Testing Accuracy with Probabilities: 0.8535488572067247
# ROC AUC Training Accuracy with Probabilities: 0.8615624865460205
# Testing Accuracy: 0.8053892215568862
# Training Accuracy: 0.8095832293486399
# Number of Estimators: 200
# ROC AUC Testing Accuracy: 0.7200279855891634
# ROC AUC Training Accuracy: 0.7309514140252958
# ROC AUC Testing Accuracy with Probabilities: 0.8506269178402325
# ROC AUC Training Accuracy with Probabilities: 0.8678208762066815
# Testing Accuracy: 0.8038922155688623
# Training Accuracy: 0.8143249313701023
# Number of Estimators: 400
# ROC AUC Testing Accuracy: 0.712690477642011
# ROC AUC Training Accuracy: 0.7366425678450049
# ROC AUC Testing Accuracy with Probabilities: 0.8464363371392574
# ROC AUC Training Accuracy with Probabilities: 0.8749526901854544
# Testing Accuracy: 0.7971556886227545
# Training Accuracy: 0.8195657599201398
# Number of Estimators: 700
# ROC AUC Testing Accuracy: 0.7063661409207955
# ROC AUC Training Accuracy: 0.7406069535949356
# ROC AUC Testing Accuracy with Probabilities: 0.8430615189439794
# ROC AUC Training Accuracy with Probabilities: 0.8817686770151731
# Testing Accuracy: 0.7919161676646707
# Training Accuracy: 0.8218118292987272
# Number of Estimators: 1000
# ROC AUC Testing Accuracy: 0.7078858977597012
# ROC AUC Training Accuracy: 0.7495852158195024
# ROC AUC Testing Accuracy with Probabilities: 0.8406693897457783
# ROC AUC Training Accuracy with Probabilities: 0.8867753244858894
# Testing Accuracy: 0.7941616766467066
# Training Accuracy: 0.8283004741702021

# %%
# # Generate submission using test.csv

# raw_test = numerize_csv_test('test.csv')
# X_test = combine_related_columns_test(raw_test)

# base_estimator = DecisionTreeClassifier(criterion="entropy", max_depth=1)
# clf = AdaBoostClassifier(estimator=base_estimator, n_estimators=200, random_state=0)
# clf.fit(X_train, y_train)
# y_test_prob_preds = clf.predict_proba(X_test)
# write_submission(y_test_prob_preds[:, 1])
