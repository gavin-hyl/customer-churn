# %%
import pandas as pd
raw = pd.read_csv('train.csv')
raw
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     1915-IOFGU  Female              0      No         No       1
# 1     6728-CZFEI  Female              0      No         No      15
# 2     3863-IUBJR    Male              0     Yes        Yes      12
# 3     5572-ZDXHY  Female              0      No         No      22
# 4     8348-HFYIV    Male              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 5338  7409-KIUTL  Female              1      No        Yes       1
# 5339  1937-OTUKY  Female              0     Yes         No      72
# 5340  2815-CPTUL    Male              1      No         No       5
# 5341  9805-FILKB    Male              0     Yes        Yes      46
# 5342  4140-MUHUG  Female              1      No         No       3
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0             Yes                No     Fiber optic                   No  ...
# ...

# %%
raw['gender'] = (raw['gender'] == 'Female').astype(int)

for header in ['Partner', 'Dependents', 'PhoneService', 'PaperlessBilling', 'Discontinued']:
    raw[header] = (raw[header] == 'Yes').astype(int)

for header in ['MultipleLines', 'OnlineSecurity', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']:
    # some here have the value no phone/internet service, which are casted to 0
    raw[header] = (raw[header] == 'Yes').astype(int)

for header in ['MonthlyCharges', 'TotalCharges', 'tenure']:
    raw[header] /= (max(raw[header]) - min(raw[header]))

raw['InternetService'] = raw['InternetService'].map({'Fiber optic': 2, 'DSL': 1, 'No': 0})
raw['Contract'] = raw['Contract'].map({'Two year': 2, 'One year': 1, 'Month-to-month': 0})
# Note that the PaymentMethod column contains some entries that are marked automatic
# that's probably correlated with discontinuation in some way.
raw['PaymentMethod'] = raw['PaymentMethod'].map({
    'Credit card (automatic)': 3,
    'Electronic check': 2,
    'Bank transfer (automatic)': 1,
    'Mailed check': 0})

# %%
raw
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents    tenure  \
# 0     1915-IOFGU       1              0        0           0  0.013889
# 1     6728-CZFEI       1              0        0           0  0.208333
# 2     3863-IUBJR       0              0        1           1  0.166667
# 3     5572-ZDXHY       1              0        0           0  0.305556
# 4     8348-HFYIV       0              0        0           0  0.027778
# ...          ...     ...            ...      ...         ...       ...
# 5338  7409-KIUTL       1              1        0           1  0.013889
# 5339  1937-OTUKY       1              0        1           0  1.000000
# 5340  2815-CPTUL       0              1        0           0  0.069444
# 5341  9805-FILKB       0              0        1           1  0.638889
# 5342  4140-MUHUG       1              1        0           0  0.041667
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...
